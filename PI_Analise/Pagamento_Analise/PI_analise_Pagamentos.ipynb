# %%
import pandas as pd
import requests as rq

# %%
df_pg = pd.read_excel("STG_PGT.xlsx")
df_pg.head(10)
# Out:
#    ID_STG_PGT  VLR_PGT_FAT   DAT_VCT COD_MDL  QTD_CLI_CAD_POS  QTD_PGT  \
# 0         451       515711  16082022     A04               22       22
# 1         452        60763  26102020     A99                2        2
# 2         453      8588195  24022019     G01               22       22
# 3         454       369084  24062018     B99               16       23
# 4         455        13054  20022021     B99                1        1
# 5         456      1206954   4012018     A04                3        5
# 6         457        21684  24122018     B07                1        1
# 7         458       341157  27032016     B99               10       11
# 8         459         3929  21032018     B05                1        1
# 9         460        12700  28112018     A05                3        3
#
#    ID_FNT_ITT DES_TIP_PSS DAT_RSS_FNT_ITT              DAT_INC_DBO
# 0          67           F      2020-01-16  2020-01-17 17:50:42.746
# ...

# %%
df_pg.dtypes
# Out:
# ID_STG_PGT          int64
# VLR_PGT_FAT         int64
# DAT_VCT             int64
# COD_MDL            object
# QTD_CLI_CAD_POS     int64
# QTD_PGT             int64
# ID_FNT_ITT          int64
# DES_TIP_PSS        object
# DAT_RSS_FNT_ITT    object
# DAT_INC_DBO        object
# dtype: object

# %%
df_pg['ID_STG_PGT'] = df_pg.ID_STG_PGT.astype('str')
df_pg['ID_FNT_ITT'] = df_pg.ID_FNT_ITT.astype('str')
df_pg.dtypes
# Out:
# ID_STG_PGT         object
# VLR_PGT_FAT         int64
# DAT_VCT             int64
# COD_MDL            object
# QTD_CLI_CAD_POS     int64
# QTD_PGT             int64
# ID_FNT_ITT         object
# DES_TIP_PSS        object
# DAT_RSS_FNT_ITT    object
# DAT_INC_DBO        object
# dtype: object

# %%
df_pg.head(50)
# Out:
#    ID_STG_PGT  VLR_PGT_FAT   DAT_VCT COD_MDL  QTD_CLI_CAD_POS  QTD_PGT  \
# 0         451       515711  16082022     A04               22       22
# 1         452        60763  26102020     A99                2        2
# 2         453      8588195  24022019     G01               22       22
# 3         454       369084  24062018     B99               16       23
# 4         455        13054  20022021     B99                1        1
# 5         456      1206954   4012018     A04                3        5
# 6         457        21684  24122018     B07                1        1
# 7         458       341157  27032016     B99               10       11
# 8         459         3929  21032018     B05                1        1
# 9         460        12700  28112018     A05                3        3
# 10        461        85390  13032019     B07                1        1
# 11        462      2024518  19122018     B07                2        2
# ...

# %%
df_pg.to_csv('df_pagamentos.csv', index=False, header=True)
